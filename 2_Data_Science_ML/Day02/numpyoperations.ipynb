# %%
import numpy as np

# %%
a = np.random.randint(1,6, (2,3))
b = np.random.randint(6,10, (3,3))
c = np.random.randint(1,9, (3,3))

# %% [markdown]
# # 1. Element Opeations

# %% [markdown]
# # Arithmetic Operations

# %%
# b + c
np.add(b,c) # element wise addition of two arrays
# Out:
# array([[12, 13, 14],
#        [10,  9, 14],
#        [12, 16, 13]], dtype=int32)

# %%
# b - c
np.subtract(b,c) # element wise subtraction of two arrays
# Out:
# array([[ 2, -1, -2],
#        [ 4,  5,  2],
#        [ 4,  2,  3]], dtype=int32)

# %%
# b * c
np.multiply(b,c) # element wise multiplication of two arrays
# Out:
# array([[35, 42, 48],
#        [21, 14, 48],
#        [32, 63, 40]], dtype=int32)

# %%
# b / c
np.divide(b,c) # element wise division of two arrays
# Out:
# array([[1.4       , 0.85714286, 0.75      ],
#        [2.33333333, 3.5       , 1.33333333],
#        [2.        , 1.28571429, 1.6       ]])

# %%
# modulo
# np.mod(b,c) # element wise modulo of two arrays
b % c
# Out:
# array([[2, 6, 6],
#        [1, 1, 2],
#        [0, 2, 3]], dtype=int32)

# %%
# a ** 2 # element wise exponentiation of an array with a scalar value
# np.pow(a, 2) # element wise exponentiation of an array with a scalar value
np.pow(b,c) # element wise exponentiation of two arrays
# Out:
# array([[  16807,  279936, 1679616],
#        [    343,      49,  262144],
#        [   4096, 4782969,   32768]], dtype=int32)

# %% [markdown]
# # Trignometric

# %%
np.sin(a)
# Out:
# array([[ 0.84147098, -0.95892427,  0.90929743],
#        [ 0.84147098, -0.7568025 , -0.95892427]])

# %%
cot = 1/np.tan(a)
cot
# Out:
# array([[ 0.64209262, -0.29581292, -0.45765755],
#        [ 0.64209262,  0.86369115, -0.29581292]])

# %% [markdown]
# # Rounding Operations

# %%
np.around(cot, 2)
# Out:
# array([[ 0.64, -0.3 , -0.46],
#        [ 0.64,  0.86, -0.3 ]])

# %%
np.floor(cot)
# Out:
# array([[ 0., -1., -1.],
#        [ 0.,  0., -1.]])

# %%
np.ceil(cot)
# Out:
# array([[ 1., -0., -0.],
#        [ 1.,  1., -0.]])

# %% [markdown]
# # Matrix Operations

# %%
a = np.random.randint(1,50, (2,3))
b = np.random.randint(6,100, (3,3))

# %%
a.shape
# Out:
# (2, 3)

# %%
b.shape
# Out:
# (3, 3)

# %%
# a @ b # matrix multiplication of two arrays
# np.dot(a,b) # matrix multiplication of two arrays
res = a.dot(b) # matrix multiplication of two arrays
res
# Out:
# array([[8153, 6786, 6075],
#        [4367, 3593, 3427]], dtype=int32)

# %%
res.shape
# Out:
# (2, 3)

# %%
# Inverse Matrix
det = np.linalg.det(b) # determinant of a matrix
det
# Out:
# array([[ 0.66646388, -0.13368821, -0.39041825],
#        [-0.57961977,  0.1356654 ,  0.33703422],
#        [-0.23923954,  0.0313308 ,  0.15406844]])

# %%
np.linalg.inv(b) # inverse of a matrix
# Out:
# array([[ 0.66646388, -0.13368821, -0.39041825],
#        [-0.57961977,  0.1356654 ,  0.33703422],
#        [-0.23923954,  0.0313308 ,  0.15406844]])
