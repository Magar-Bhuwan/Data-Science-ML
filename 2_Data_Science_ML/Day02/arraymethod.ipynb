# %%
import numpy as np

# %%
arr = np.random.rand(10,50)

# %%
arr.shape
# Out:
# (10, 50)

# %%
arr.ndim
# Out:
# 2

# %%
arr.dtype
# Out:
# dtype('float64')

# %%
arr.size
# Out:
# 500

# %%
# Transpose of an array
arr_T = arr.T
arr_T.shape
# Out:
# (50, 10)

# %%
arr = np.random.randint(2,5, (3,4))
arr
# Out:
# array([[2, 3, 2, 2],
#        [2, 4, 2, 4],
#        [4, 3, 2, 2]], dtype=int32)

# %%
arr.reshape(2,3, -1)
# Out:
# array([[[2, 3],
#         [2, 2],
#         [2, 4]],
#
#        [[2, 4],
#         [4, 3],
#         [2, 2]]], dtype=int32)

# %%
flat_arry = arr.flatten()
flat_arry
# Out:
# array([2, 3, 2, 2, 2, 4, 2, 4, 4, 3, 2, 2], dtype=int32)

# %%
# arr.sum(axis=0) # column wise sum
# arr.sum(axis=1) # row wise sum
arr.sum() # total sum of all elements in the array
# Out:
# np.int64(32)

# %%
arr.prod(axis = 1) # row wise product of all elements in the array
# Out:
# array([24, 64, 48])

# %%
arr.cumsum(axis =0) # cumulative sum along the column
# Out:
# array([[ 2,  3,  2,  2],
#        [ 4,  7,  4,  6],
#        [ 8, 10,  6,  8]])

# %%
arr.max()
# Out:
# np.int32(4)

# %%
arr.min(axis=0) # column wise minimum
# Out:
# array([2, 3, 2, 2], dtype=int32)

# %%
arr.argmax(axis=0) # column wise index of maximum value
# Out:
# array([2, 1, 0, 1])

# %%
arr1 = np.random.randint(1,100, (3,4))
arr2 = np.random.randint(1,100, (3,4))

# %%
arr1
# Out:
# array([[11, 84, 34, 89],
#        [36, 17, 37, 63],
#        [24, 33, 12, 60]], dtype=int32)

# %%
merged = np.concatenate((arr1, arr2), axis = 0) # row wise merging of two arrays
merged
# Out:
# array([[11, 84, 34, 89],
#        [36, 17, 37, 63],
#        [24, 33, 12, 60],
#        [81, 84, 77,  8],
#        [12, 74, 47, 75],
#        [79, 74, 86, 12]], dtype=int32)
