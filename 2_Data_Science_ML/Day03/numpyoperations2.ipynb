# %%
import numpy as np

# %%
# 4X + 2Y = 8
# 5X + 3Y = 9

# %%
A = np.array([[4, 2], [5, 3]])
C = np.array([8, 9])

# %%
A_1 = np.linalg.inv(A)
print(A_1)
# Out:
# [[ 1.5 -1. ]
#  [-2.5  2. ]]

# %%
X = np
