# %% [markdown]
# Why Numpy over python for loop?

# %%
import numpy as np
import time

# %%
a = np.random.rand(10_000_000)
b = np.random.rand(10_000_000)

# %%
st = time.time()

result =[]
for num1, num2 in zip(list(a), list(b)):
    result.append(num1*num2)

end = time.time()

print("Time taken for list comprehension: ", end-st)
# Out:
# Time taken for list comprehension:  2.7740302085876465

# %%
# Comprehension

st = time.time()

result =[num1*num2 for num1, num2 in zip(list(a), list(b))]

end = time.time()

print("Time taken for list comprehension: ", end-st)
# Out:
# Time taken for list comprehension:  1.784912109375

# %%
# Numpy Operations

st = time.time()
result = np.multiply(a, b)
end = time.time()
print("Time taken for numpy multiplication: ", end-st)
# Out:
# Time taken for numpy multiplication:  0.1285402774810791
