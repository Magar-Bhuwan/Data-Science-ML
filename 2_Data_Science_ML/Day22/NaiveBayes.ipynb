# %% [markdown]
# ## Conditional Probability
# Conditional probability is the likelihood of an event occurring, given that another related event has already happened. It factors in new information to narrow the possible outcomes, calculating the probability of both events happening together, divided by the probability of the "given" event.

# %% [markdown]
# ![image.png](attachment:image.png)
